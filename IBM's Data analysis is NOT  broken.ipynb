# %%
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt

# Dataset URL
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_2.csv"

# Fetch the data
response = requests.get(URL)
dataset_part_2_csv = response.content

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(io.StringIO(dataset_part_2_csv.decode('utf-8')))

# Display the first 5 rows
print(df.head())

# Plot the graph
sns.catplot(y="PayloadMass", x="FlightNumber", hue="Class", data=df, aspect=5)
plt.xlabel("Flight Number", fontsize=20)
plt.ylabel("Payload Mass (kg)", fontsize=20)
plt.show()
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# 0            0  B0003  -80.577366  28.561857      0
# 1            0  B0005  -80.577366  28.561857      0
# 2            0  B0007  -80.577366  28.561857      0
# 3            0  B1003 -120.610829  34.632093      0
# 4            0  B1004  -80.577366  28.561857      0

# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\vincenzo\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vincenzo\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vincenzo\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vincenzo\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vincenzo\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vincenzo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\vincenzo\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: seaborn in c:\users\vincenzo\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\vincenzo\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\vincenzo\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\vincenzo\anaconda3\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vincenzo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vincenzo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vincenzo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vincenzo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vincenzo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\vincenzo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vincenzo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vincenzo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vincenzo\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vincenzo\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vincenzo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %% [markdown]
# TASK 1: Visualize the relationship between Flight Number and Launch Site
# Use the function catplot to plot FlightNumber vs LaunchSite, set the parameter x parameter to FlightNumber,set the y to Launch Site and set the parameter hue to 'class'
# # Plot a scatter point chart with x axis to be Flight Number and y axis to be the launch site, and hue to be the class value

# %%
# Visualize the relationship between Flight Number and Launch Site
sns.catplot(x="FlightNumber", y="LaunchSite", hue="Class", data=df, aspect=5)

# Set plot labels
plt.xlabel("Flight Number", fontsize=20)
plt.ylabel("Launch Site", fontsize=20)

# Show the plot
plt.show()

# %% [markdown]
# TASK 2: Visualize the relationship between Payload Mass and Launch Site
# We also want to observe if there is any relationship between launch sites and their payload mass.
#
# # Plot a scatter point chart with x axis to be Pay Load Mass (kg) and y axis to be the launch site, and hue to be the class value
# Now if you observe Payload Mass Vs. Launch Site scatter point chart you will find for the VAFB-SLC launchsite there are no rockets launched for heavypayload mass(greater than 10000).

# %%
# Visualize the relationship between Payload Mass and Launch Site
sns.catplot(x="PayloadMass", y="LaunchSite", hue="Class", data=df, aspect=5)

# Set plot labels
plt.xlabel("Payload Mass (kg)", fontsize=20)
plt.ylabel("Launch Site", fontsize=20)

# Show the plot
plt.show()

# %% [markdown]
# TASK 3: Visualize the relationship between success rate of each orbit type
# Next, we want to visually check if there are any relationship between success rate and orbit type.
#
# Let's create a bar chart for the sucess rate of each orbit
# # HINT use groupby method on Orbit column and get the mean of Class column

# %%
# Group by the 'Orbit' column and calculate the mean success rate
success_rate_per_orbit = df.groupby('Orbit')['Class'].mean().reset_index()

# Plot a bar chart for success rate of each orbit type
sns.barplot(x='Orbit', y='Class', data=success_rate_per_orbit)

# Set plot labels and title
plt.xlabel("Orbit Type", fontsize=14)
plt.ylabel("Success Rate", fontsize=14)
plt.title("Success Rate by Orbit Type", fontsize=16)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# TASK 4: Visualize the relationship between FlightNumber and Orbit type
# For each orbit, we want to see if there is any relationship between FlightNumber and Orbit type.
# # Plot a scatter point chart with x axis to be FlightNumber and y axis to be the Orbit, and hue to be the class value

# %%
# Visualize the relationship between Flight Number and Orbit type
sns.catplot(x="FlightNumber", y="Orbit", hue="Class", data=df, aspect=5)

# Set plot labels and title
plt.xlabel("Flight Number", fontsize=20)
plt.ylabel("Orbit Type", fontsize=20)
plt.title("Flight Number vs Orbit Type", fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# TASK 5: Visualize the relationship between Payload Mass and Orbit type
# Similarly, we can plot the Payload Mass vs. Orbit scatter point charts to reveal the relationship between Payload Mass and Orbit type
#
# # Plot a scatter point chart with x axis to be Payload Mass and y axis to be the Orbit, and hue to be the class value

# %%
# Visualize the relationship between Payload Mass and Orbit type
sns.catplot(x="PayloadMass", y="Orbit", hue="Class", data=df, aspect=5)

# Set plot labels and title
plt.xlabel("Payload Mass (kg)", fontsize=20)
plt.ylabel("Orbit Type", fontsize=20)
plt.title("Payload Mass vs Orbit Type", fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# TASK 6: Visualize the launch success yearly trend
# You can plot a line chart with x axis to be Year and y axis to be average success rate, to get the average launch success trend.
#
# The function will help you get the year from the date:

# %%
# A function to Extract years from the date 
year = []
def Extract_year():
    for i in df["Date"]:
        year.append(i.split("-")[0])
    return year

# Extract years and add to dataframe
df['Year'] = Extract_year()

# Group by Year and calculate the mean success rate
yearly_success_rate = df.groupby('Year')['Class'].mean().reset_index()

# Create the line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='Class', data=yearly_success_rate, marker='o')

# Set plot labels and title
plt.xlabel("Year", fontsize=14)
plt.ylabel("Success Rate", fontsize=14)
plt.title("Yearly Launch Success Trend", fontsize=16)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
Features Engineering
By now, you should obtain some preliminary insights about how each important variable would affect the success rate, we will select the features that will be used in success prediction in the future module.

# %%
features = df[['FlightNumber', 'PayloadMass', 'Orbit', 'LaunchSite', 'Flights', 'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Serial']]
features.head()
# Out:
#    FlightNumber  PayloadMass Orbit    LaunchSite  Flights  GridFins  Reused  \
# 0             1  6104.959412   LEO  CCAFS SLC 40        1     False   False
# 1             2   525.000000   LEO  CCAFS SLC 40        1     False   False
# 2             3   677.000000   ISS  CCAFS SLC 40        1     False   False
# 3             4   500.000000    PO   VAFB SLC 4E        1     False   False
# 4             5  3170.000000   GTO  CCAFS SLC 40        1     False   False
#
#     Legs LandingPad  Block  ReusedCount Serial
# 0  False        NaN    1.0            0  B0003
# 1  False        NaN    1.0            0  B0005
# 2  False        NaN    1.0            0  B0007
# 3  False        NaN    1.0            0  B1003
# 4  False        NaN    1.0            0  B1004

# %% [markdown]
# TASK 7: Create dummy variables to categorical columns
# Use the function get_dummies and features dataframe to apply OneHotEncoder to the column Orbits, LaunchSite, LandingPad, and Serial. Assign the value to the variable features_one_hot, display the results using the method head. Your result dataframe must include all features including the encoded ones.

# %%
# Import pandas if not already imported
import pandas as pd

# Perform one-hot encoding on specified categorical columns
features_one_hot = pd.get_dummies(features, columns=['Orbit', 'LaunchSite', 'LandingPad', 'Serial'])

# Display the first few rows of the resulting dataframe
print(features_one_hot.head())

# Display information about the resulting dataframe
print("\nDataframe Info:")
print(features_one_hot.info())
# Out:
#    FlightNumber  PayloadMass  Flights  GridFins  Reused   Legs  Block  \
# 0             1  6104.959412        1     False   False  False    1.0
# 1             2   525.000000        1     False   False  False    1.0
# 2             3   677.000000        1     False   False  False    1.0
# 3             4   500.000000        1     False   False  False    1.0
# 4             5  3170.000000        1     False   False  False    1.0
#
#    ReusedCount  Orbit_ES-L1  Orbit_GEO  ...  Serial_B1048  Serial_B1049  \
# 0            0        False      False  ...         False         False
# 1            0        False      False  ...         False         False
# 2            0        False      False  ...         False         False
# 3            0        False      False  ...         False         False
# 4            0        False      False  ...         False         False
#
#    Serial_B1050  Serial_B1051  Serial_B1054  Serial_B1056  Serial_B1058  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    Serial_B1059  Serial_B1060  Serial_B1062
# 0         False         False         False
# 1         False         False         False
# 2         False         False         False
# 3         False         False         False
# 4         False         False         False
#
# [5 rows x 80 columns]
#
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 80 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   FlightNumber                         90 non-null     int64
#  1   PayloadMass                          90 non-null     float64
#  2   Flights                              90 non-null     int64
#  3   GridFins                             90 non-null     bool
#  4   Reused                               90 non-null     bool
#  5   Legs                                 90 non-null     bool
#  6   Block                                90 non-null     float64
#  7   ReusedCount                          90 non-null     int64
#  8   Orbit_ES-L1                          90 non-null     bool
#  9   Orbit_GEO                            90 non-null     bool
#  10  Orbit_GTO                            90 non-null     bool
#  11  Orbit_HEO                            90 non-null     bool
#  12  Orbit_ISS                            90 non-null     bool
#  13  Orbit_LEO                            90 non-null     bool
#  14  Orbit_MEO                            90 non-null     bool
#  15  Orbit_PO                             90 non-null     bool
#  16  Orbit_SO                             90 non-null     bool
#  17  Orbit_SSO                            90 non-null     bool
#  18  Orbit_VLEO                           90 non-null     bool
#  19  LaunchSite_CCAFS SLC 40              90 non-null     bool
#  20  LaunchSite_KSC LC 39A                90 non-null     bool
#  21  LaunchSite_VAFB SLC 4E               90 non-null     bool
#  22  LandingPad_5e9e3032383ecb267a34e7c7  90 non-null     bool
#  23  LandingPad_5e9e3032383ecb554034e7c9  90 non-null     bool
#  24  LandingPad_5e9e3032383ecb6bb234e7ca  90 non-null     bool
#  25  LandingPad_5e9e3032383ecb761634e7cb  90 non-null     bool
#  26  LandingPad_5e9e3033383ecbb9e534e7cc  90 non-null     bool
#  27  Serial_B0003                         90 non-null     bool
#  28  Serial_B0005                         90 non-null     bool
#  29  Serial_B0007                         90 non-null     bool
#  30  Serial_B1003                         90 non-null     bool
#  31  Serial_B1004                         90 non-null     bool
#  32  Serial_B1005                         90 non-null     bool
#  33  Serial_B1006                         90 non-null     bool
#  34  Serial_B1007                         90 non-null     bool
#  35  Serial_B1008                         90 non-null     bool
#  36  Serial_B1010                         90 non-null     bool
#  37  Serial_B1011                         90 non-null     bool
#  38  Serial_B1012                         90 non-null     bool
#  39  Serial_B1013                         90 non-null     bool
#  40  Serial_B1015                         90 non-null     bool
#  41  Serial_B1016                         90 non-null     bool
#  42  Serial_B1017                         90 non-null     bool
#  43  Serial_B1018                         90 non-null     bool
#  44  Serial_B1019                         90 non-null     bool
#  45  Serial_B1020                         90 non-null     bool
#  46  Serial_B1021                         90 non-null     bool
#  47  Serial_B1022                         90 non-null     bool
#  48  Serial_B1023                         90 non-null     bool
#  49  Serial_B1025                         90 non-null     bool
#  50  Serial_B1026                         90 non-null     bool
#  51  Serial_B1028                         90 non-null     bool
#  52  Serial_B1029                         90 non-null     bool
#  53  Serial_B1030                         90 non-null     bool
#  54  Serial_B1031                         90 non-null     bool
#  55  Serial_B1032                         90 non-null     bool
#  56  Serial_B1034                         90 non-null     bool
#  57  Serial_B1035                         90 non-null     bool
#  58  Serial_B1036                         90 non-null     bool
#  59  Serial_B1037                         90 non-null     bool
#  60  Serial_B1038                         90 non-null     bool
#  61  Serial_B1039                         90 non-null     bool
#  62  Serial_B1040                         90 non-null     bool
#  63  Serial_B1041                         90 non-null     bool
#  64  Serial_B1042                         90 non-null     bool
#  65  Serial_B1043                         90 non-null     bool
#  66  Serial_B1044                         90 non-null     bool
#  67  Serial_B1045                         90 non-null     bool
#  68  Serial_B1046                         90 non-null     bool
#  69  Serial_B1047                         90 non-null     bool
#  70  Serial_B1048                         90 non-null     bool
#  71  Serial_B1049                         90 non-null     bool
#  72  Serial_B1050                         90 non-null     bool
#  73  Serial_B1051                         90 non-null     bool
#  74  Serial_B1054                         90 non-null     bool
#  75  Serial_B1056                         90 non-null     bool
#  76  Serial_B1058                         90 non-null     bool
#  77  Serial_B1059                         90 non-null     bool
#  78  Serial_B1060                         90 non-null     bool
#  79  Serial_B1062                         90 non-null     bool
# dtypes: bool(75), float64(2), int64(3)
# memory usage: 10.2 KB
# None

# %% [markdown]
# TASK 8: Cast all numeric columns to float64
# Now that our features_one_hot dataframe only contains numbers, cast the entire dataframe to variable type float64
