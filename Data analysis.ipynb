# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
import piplite
await piplite.install('seaborn')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import piplite
#       2 await piplite.install('seaborn')
#
# ModuleNotFoundError: No module named 'piplite'

# %%
filepath='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv'

# %%
await download(filepath, "housing.csv")
file_name="housing.csv"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 await download(filepath, "housing.csv")
#       2 file_name="housing.csv"
#
# NameError: name 'download' is not defined

# %%
df = pd.read_csv(file_name)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv(file_name)
#       2 df.head()
#
# NameError: name 'file_name' is not defined

# %%
#Enter Your Code, Execute and take the Screenshot

# Load the dataset
file_name = "housing.csv"
df = pd.read_csv(file_name)

# Display the data types of each column
print(df.dtypes)
df.describe()
# Load the dataset
file_name = "housing.csv"
df = pd.read_csv(file_name)

# Drop the columns "id" and "Unnamed: 0" from the DataFrame
df.drop(columns=["id", "Unnamed: 0"], axis=1, inplace=True)

# Obtain a statistical summary of the data
print(df.describe())
print("number of NaN values for the column bedrooms :", df['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", df['bathrooms'].isnull().sum())
mean=df['bedrooms'].mean()
df['bedrooms'].replace(np.nan,mean, inplace=True)
mean=df['bathrooms'].mean()
df['bathrooms'].replace(np.nan,mean, inplace=True)
print("number of NaN values for the column bedrooms :", df['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", df['bathrooms'].isnull().sum())
# Count the number of houses with unique floor values
floor_counts = df['floors'].value_counts()

# Convert the result to a DataFrame
floor_counts_df = floor_counts.to_frame()

# Display the DataFrame
print(floor_counts_df)
# Create a boxplot to compare prices based on waterfront view
sns.boxplot(x='waterfront', y='price', data=df)

# Display the plot
plt.title('Boxplot of House Prices by Waterfront View')
plt.xlabel('Waterfront View (0 = No, 1 = Yes)')
plt.ylabel('Price')
plt.show()
#Enter Your Code, Execute and take the Screenshot

# Create a regression plot to determine the correlation between sqft_above and price
sns.regplot(x='sqft_above', y='price', data=df)

# Display the plot
plt.title('Regression Plot of Price vs. Sqft Above')
plt.xlabel('Sqft Above')
plt.ylabel('Price')
plt.show()
df.corr()['price'].sort_values()
X = df[['long']]
Y = df['price']
lm = LinearRegression()
lm.fit(X,Y)
lm.score(X, Y)
#Enter Your Code, Execute and take the Screenshot
# Define the predictor (independent variable) and target (dependent variable)
X = df[['sqft_living']]  # Feature
Y = df['price']          # Target

# Create a Linear Regression model
lm = LinearRegression()

# Fit the model
lm.fit(X, Y)

# Calculate the R^2 value
r2_score = lm.score(X, Y)

# Display the R^2 value
print(f'R^2 value: {r2_score}')
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]     
# Define the list of features
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", 
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]

# Define the predictor (independent variables) and target (dependent variable)
X = df[features]  # Features
Y = df['price']   # Target

# Create a Linear Regression model
lm = LinearRegression()

# Fit the model
lm.fit(X, Y)

# Calculate the R^2 value
r2_score = lm.score(X, Y)

# Display the R^2 value
print(f'R^2 value: {r2_score}')
# Define the list of features
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", 
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]

# Define the pipeline steps
pipeline_steps = [
    ('scale', StandardScaler()),
    ('polynomial', PolynomialFeatures(include_bias=False)),
    ('model', LinearRegression())
]

# Create the pipeline object
pipeline = Pipeline(pipeline_steps)

# Define the predictor (independent variables) and target (dependent variable)
X = df[features]  # Features
Y = df['price']   # Target

# Fit the pipeline to the data
pipeline.fit(X, Y)

# Calculate the R^2 value
r2_score = pipeline.score(X, Y)

# Display the R^2 value
print(f'R^2 value: {r2_score}')
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
print("done")
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]    
X = df[features]
Y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)   #test and training sets, like every good learning model


print("number of test samples:", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
from sklearn.linear_model import Ridge
#Enter Your Code, Execute and take the Screenshot
# Define the list of features
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", 
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]

# Define the predictor (independent variables) and target (dependent variable)
X = df[features]  # Features
Y = df['price']   # Target

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)    #test and training sets, like every good learning model

print("number of test samples:", x_test.shape[0])
print("number of training samples:", x_train.shape[0])

# Create and fit the Ridge regression model to generalize the model, so it can adapt to unusual variable
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(x_train, y_train)

# Calculate the R^2 value using the test data
r2_score = ridge_model.score(x_test, y_test)

# Display the R^2 value
print(f'R^2 value on test data: {r2_score}')

# Define the list of features
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", 
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]

# Define the predictor (independent variables) and target (dependent variable)
X = df[features]  # Features
Y = df['price']   # Target

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

# Perform a second order polynomial transform on the training and testing data
poly = PolynomialFeatures(degree=2, include_bias=False)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# Create and fit the Ridge regression model with regularization parameter alpha = 0.1
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(x_train_poly, y_train)

# Calculate the R^2 value using the test data
r2_score = ridge_model.score(x_test_poly, y_test)

# Display the R^2 value
print(f'R^2 value on test data with polynomial features: {r2_score}')
